# %%
import numpy as np 
import pandas as pd 





data = pd.read_csv('../input/spammmmmmmmmmmm/spam_email.txt',sep=' ')

# data.describe(include='all')
onlydata=data.loc[:,'make':'cap_total']
onlydata.describe(include='all')
# Out:
#               make      address          all           3d          our  \
# count  4601.000000  4601.000000  4601.000000  4601.000000  4601.000000
# mean      0.104553     0.213015     0.280656     0.065425     0.312223
# std       0.305358     1.290575     0.504143     1.395151     0.672513
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.420000     0.000000     0.380000
# max       4.540000    14.280000     5.100000    42.810000    10.000000
#
#               over       remove     internet        order         mail  ...  \
# count  4601.000000  4601.000000  4601.000000  4601.000000  4601.000000  ...
# mean      0.095901     0.114208     0.105295     0.090067     0.239413  ...
# std       0.273824     0.391441     0.401071     0.278616     0.644755  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 75%       0.000000     0.000000     0.000000     0.000000     0.160000  ...
# max       5.880000     7.270000    11.110000     5.260000    18.180000  ...
#
#         conference      semicol        paren      bracket         bang  \
# count  4601.000000  4601.000000  4601.000000  4601.000000  4601.000000
# mean      0.031869     0.038575     0.139030     0.016976     0.269071
# std       0.285735     0.243471     0.270355     0.109394     0.815672
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.065000     0.000000     0.000000
# 75%       0.000000     0.000000     0.188000     0.000000     0.315000
# max      10.000000     4.385000     9.752000     4.081000    32.478000
#
#             dollar        pound      cap_avg     cap_long     cap_total
# count  4601.000000  4601.000000  4601.000000  4601.000000   4601.000000
# mean      0.075811     0.044238     5.191515    52.172789    283.289285
# std       0.245882     0.429342    31.729449   194.891310    606.347851
# min       0.000000     0.000000     1.000000     1.000000      1.000000
# 25%       0.000000     0.000000     1.588000     6.000000     35.000000
# 50%       0.000000     0.000000     2.276000    15.000000     95.000000
# 75%       0.052000     0.000000     3.706000    43.000000    266.000000
# max       6.003000    19.829000  1102.500000  9989.000000  15841.000000
#
# [8 rows x 57 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
X=onlydata.values
yspam=data.values[:,57]
y=np.zeros((yspam.size))
y[yspam=='spam']=1
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 0)
# Standardize the x_train and x_test datasets
std_scaler = preprocessing.StandardScaler().fit(X_train)
X_train_scaled = std_scaler.transform(X_train)
X_test_scaled = std_scaler.transform(X_test)

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
pca= PCA(n_components=2)
fig, (plttrain, plttest) = plt.subplots(1, 2)
datavl1=pca.fit_transform(X_train_scaled)
g11=datavl1[(y_train==1)]
g12=datavl1[(y_train==0)]
plttrain.set_title('Train values :'+ str(X_train_scaled.shape))
plttrain.scatter(g11[:,0],g11[:,1],marker='o',c="green")
plttrain.scatter(g12[:,0],g12[:,1],marker='+',c="red")
plttrain.legend(['lable 1','lable 0'])
datavl2=pca.fit_transform(X_test_scaled)
g21=datavl2[(y_test==1)]
g22=datavl2[(y_test==0)]
plttest.set_title('Test values :'+str(X_test_scaled.shape))
plttest.scatter(g21[:,0],g21[:,1],marker='o',c="brown")
plttest.scatter(g22[:,0],g22[:,1],marker='+',c="yellow")
plttest.legend(['lable 1','lable 0'])
plt.savefig('lettersCG_Xtraintext.png')

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
pca= PCA(n_components=2)
# fig, (plttrain, plttest) = plt.subplots(1, 2)
datavlx=pca.fit_transform(X)
gx1=datavlx[(y==1)]
gx2=datavlx[(y==0)]
plt.title('Train values :'+ str(X.shape))
plt.scatter(gx1[:,0],gx1[:,1],marker='o',c="pink")
plt.scatter(gx2[:,0],gx2[:,1],marker='+',c="purple")
plt.legend(['lable 1','lable 0'])
plt.savefig('spam_X.png')

# %%
class RatingModel:
    def __init__(self, y_, y_Pr):
      self.y_=y_
      self.y_Pr=y_Pr
      self.TN=np.size(y_Pr[(y_Pr==-1)&(y_==y_Pr)])
      self.FN=np.size(y_Pr[(y_Pr==-1)&(y_!=y_Pr)])
      self.TP=np.size(y_Pr[(y_Pr==1)&(y_==y_Pr)])
      self.FP=np.size(y_Pr[(y_Pr==1)&(y_!=y_Pr)])
      self.y_[self.y_==0]=-1
      self.y_Pr[self.y_Pr==0]=-1
      # assert self.y_.set={1, -1}
      # assert self.y_Pr.set={1, -1}
    def __rep__():
        return ""
    def accur_Error(self, y_, y_Pr):
        rs=(self.TP+self.TN)/(y_.size)
        return [rs,(1-rs)]
    def sensitivity(self):
        P=np.size(self.y_[self.y_==1])
        return (self.TP)/(P)
    def specificity(self):
        N=np.size(self.y_[self.y_==-1])
        return (self.TN)/(N)
    def precision(self):
        rs=self.TP+self.FP
        return (self.TP)/(rs)
    def recall(self):
        rs=self.TP+self.FN
        return (self.TP)/(rs)
    def rating(self):
        return [self.accur_Error(self.y_, self.y_Pr), self.sensitivity(), self.specificity(), self.precision(), self.recall()]
class DecisionStump:
    def __init__(self, T=100):
        self.T = T
        pass

    def fit(self, X: np.ndarray, y: np.ndarray, sample_weight: np.ndarray):
        T = self.T
        W=sample_weight
        nrow, ncol = X.shape
        assert nrow == y.size

        bestn = 0
        bestd = 1
        bestp = 0
        minerr = W.sum()
        for i in range(ncol):
            err, d, p = self._optimize(X[:, i], y, W, T)
            if err < minerr:
                minerr = err
                bestn = i
                bestd = d
                bestp = p
        
        self.features = ncol
        self.bestn = bestn
        self.bestd = bestd
        self.bestp = bestp

        return self

    def _optimize(self, X, y, W, T):
        X = X.flatten()
        min_x, max_x = X.min(), X.max()
        len_x = max_x - min_x
        
        bestd = 1
        bestp = min_x
        minerr = W.sum()

        if len_x > 0.0:
            for p in np.arange(min_x, max_x, len_x/T):
                for d in [-1, 1]:
                    gy = np.ones((y.size))
                    gy[X*d < p*d] = -1
                    err = np.sum((gy != y)*W)
                    if err < minerr:
                        minerr = err
                        bestd = d
                        bestp = p

        return minerr, bestd, bestp

    def predict(self, test_set : np.ndarray):
        nrow, ncol = test_set.shape

        assert ncol == self.features

        icol = test_set[:, self.bestn]
        h = np.ones((nrow))
        h[icol*self.bestd < self.bestp*self.bestd] = -1
        return h
class AdaBoost:
    def __init__(self , T, hmodel = DecisionStump()):
        self.T=T
        self.hmodel=hmodel
    def fit(self, X: np.ndarray, y_: np.ndarray, verbose=False):
      n = X.shape[0]
      T = self.T
      y=y_
      y[y==0]=-1
    # init numpy arrays
      self.D = np.zeros(shape=(T, n))
      self.h = np.zeros(shape=T, dtype=object)
      self.alpha = np.zeros(shape=T)
      self.errors = np.zeros(shape=T)
      self.ratting = np.zeros(shape=(T,2))

      # initialize weights uniformly
      self.D[0] = np.ones(shape=n) / n

      for t in range(T):
          # fit  weak learner
          D_ = self.D[t]
          h_ = DecisionStump(60)
          h_ = h_.fit(X, y, D_)

          # calculate error and stump weight from weak learner prediction
          Pr_ = h_.predict(X)
          error_ = D_[(Pr_ != y)].sum()# / n
          alpha_ = np.log((1 - error_) / error_) / 2

          # update sample weights
          D_new = (
              D_ * np.exp(-alpha_ * y * Pr_)
          )
          
          D_new /= D_new.sum()

          # If not final iteration, update sample weights for t+1
          if t+1 < T:
              self.D[t+1] = D_new

          # save results of iteration
          self.h[t] = h_
          self.alpha[t] = alpha_
          self.errors[t] = error_
          # ae=np.array([0,0])
          if t>0:
            Pr_temp=self.predictmodul(X,t)
            modelra=RatingModel(y, Pr_temp)
            self.ratting[t,:]=modelra.accur_Error(y, Pr_temp)
          if verbose: print('TruongThanhTrieu {0}-th weak TruongThanhTrieu: accuracy={1}, error={2}'.format (t, self.ratting[t,0], self.ratting[t,1]))
      return self
    def predict(self, X):
        Pr_ = np.array([h_.predict(X) for h_ in self.h])
        return np.sign(np.dot(self.alpha, Pr_))
    def predictmodul(self, X, i):
        h_temp=self.h[:i]
        alpha_temp=self.alpha[:i]
        Pr_ = np.array([h_.predict(X) for h_ in h_temp])
        return np.sign(np.dot(alpha_temp, Pr_))

# %%
model=AdaBoost(60)
model=model.fit(X_train_scaled, y_train,  True )
Pr=model.predict( X_test_scaled)
Pr[(Pr==0)]=-1
# print(Pr, y_test)
# Out:
# TruongThanhTrieu 0-th weak TruongThanhTrieu: accuracy=0.0, error=0.0
# TruongThanhTrieu 1-th weak TruongThanhTrieu: accuracy=0.7869565217391304, error=0.21304347826086956
# TruongThanhTrieu 2-th weak TruongThanhTrieu: accuracy=0.7869565217391304, error=0.21304347826086956
# TruongThanhTrieu 3-th weak TruongThanhTrieu: accuracy=0.8400621118012422, error=0.15993788819875776
# TruongThanhTrieu 4-th weak TruongThanhTrieu: accuracy=0.8295031055900621, error=0.17049689440993787
# TruongThanhTrieu 5-th weak TruongThanhTrieu: accuracy=0.8748447204968944, error=0.12515527950310557
# TruongThanhTrieu 6-th weak TruongThanhTrieu: accuracy=0.8605590062111801, error=0.1394409937888199
# TruongThanhTrieu 7-th weak TruongThanhTrieu: accuracy=0.8785714285714286, error=0.12142857142857144
# TruongThanhTrieu 8-th weak TruongThanhTrieu: accuracy=0.877639751552795, error=0.12236024844720494
# TruongThanhTrieu 9-th weak TruongThanhTrieu: accuracy=0.8835403726708074, error=0.11645962732919257
# TruongThanhTrieu 10-th weak TruongThanhTrieu: accuracy=0.8835403726708074, error=0.11645962732919257
# TruongThanhTrieu 11-th weak TruongThanhTrieu: accuracy=0.8885093167701863, error=0.1114906832298137
# TruongThanhTrieu 12-th weak TruongThanhTrieu: accuracy=0.8906832298136645, error=0.10931677018633545
# TruongThanhTrieu 13-th weak TruongThanhTrieu: accuracy=0.8922360248447205, error=0.10776397515527947
# TruongThanhTrieu 14-th weak TruongThanhTrieu: accuracy=0.8947204968944099, error=0.10527950310559009
# TruongThanhTrieu 15-th weak TruongThanhTrieu: accuracy=0.8959627329192547, error=0.10403726708074534
# TruongThanhTrieu 16-th weak TruongThanhTrieu: accuracy=0.9, error=0.09999999999999998
# TruongThanhTrieu 46-th weak TruongThanhTrieu: accuracy=0.927639751552795, error=0.07236024844720501
# TruongThanhTrieu 47-th weak TruongThanhTrieu: accuracy=0.9316770186335404, error=0.06832298136645965
# TruongThanhTrieu 48-th weak TruongThanhTrieu: accuracy=0.9263975155279504, error=0.07360248447204965
# TruongThanhTrieu 49-th weak TruongThanhTrieu: accuracy=0.9322981366459627, error=0.06770186335403727
# TruongThanhTrieu 50-th weak TruongThanhTrieu: accuracy=0.9273291925465839, error=0.07267080745341614
# TruongThanhTrieu 51-th weak TruongThanhTrieu: accuracy=0.9329192546583851, error=0.0670807453416149
# TruongThanhTrieu 52-th weak TruongThanhTrieu: accuracy=0.9285714285714286, error=0.0714285714285714
# TruongThanhTrieu 53-th weak TruongThanhTrieu: accuracy=0.9335403726708075, error=0.06645962732919253
# TruongThanhTrieu 54-th weak TruongThanhTrieu: accuracy=0.9295031055900621, error=0.0704968944099379
# TruongThanhTrieu 55-th weak TruongThanhTrieu: accuracy=0.9329192546583851, error=0.0670807453416149
# TruongThanhTrieu 56-th weak TruongThanhTrieu: accuracy=0.929192546583851, error=0.07080745341614902
# TruongThanhTrieu 57-th weak TruongThanhTrieu: accuracy=0.9329192546583851, error=0.0670807453416149
# TruongThanhTrieu 58-th weak TruongThanhTrieu: accuracy=0.9285714285714286, error=0.0714285714285714
# TruongThanhTrieu 59-th weak TruongThanhTrieu: accuracy=0.9335403726708075, error=0.06645962732919253

# %%
ra_Xtest = np.zeros(shape=(model.T,2))
for i in range(1,model.T):
  Pr_i=model.predictmodul(X_test_scaled,i)
  modelra=RatingModel(y_test, Pr_i)
  ra_Xtest[i,:]=modelra.accur_Error(y_test, Pr_i)
ra_Xtrain = np.zeros(shape=(model.T,2))
for i in range(1,model.T):
  Pr_i=model.predictmodul(X_train_scaled,i)
  modelra=RatingModel(y_train, Pr_i)
  ra_Xtrain[i,:]=modelra.accur_Error(y_train, Pr_i)
iter=range(model.T)
plt.plot(iter,ra_Xtest[:,0],'y-', label='Test accuracy')
plt.plot(iter,ra_Xtest[:,1],'r-', label='Test error')
plt.plot(iter,ra_Xtrain[:,0],'y--', label='Train accuracy')
plt.plot(iter,ra_Xtrain[:,1],'r--', label='Train error')
plt.legend(loc='center right')
plt.xlabel('Iter')
plt.ylabel('Loss/Accuracy')
plt.savefig('spam_model.png')

# %%
sumerror=0;
y_new=y_test
y_new[y_new==0]=-1

gT1=datavl2[(Pr==1)]
gT0=datavl2[(Pr==-1)]
gF1=datavl2[(y_new!=Pr)&(Pr==1)]
gF0=datavl2[(y_new!=Pr)&(Pr==-1)]
plt.title('Test values errors :'+str(sumerror)+'/ '+str(X_test_scaled.shape[0]))
plt.scatter(gT1[:,0],gT1[:,1], marker='*')
plt.scatter(gT0[:,0],gT0[:,1], marker='x')
plt.scatter(gF1[:,0],gF1[:,1], marker='s')
plt.scatter(gF0[:,0],gF0[:,1], c="y", marker='+')
plt.legend(['TP C','TN G','FP C','FN G'])
plt.savefig('spambase_Xtexterror.png')
